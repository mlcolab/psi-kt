# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import operator
from utils import *

# %%
# !pip install pyvis==0.3.1
# Out:
# Collecting pyvis==0.3.1
#   Downloading pyvis-0.3.1.tar.gz (748 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 748.9/748.9 kB 12.5 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jinja2>=2.9.6 in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from pyvis==0.3.1) (3.1.2)
# Requirement already satisfied: networkx>=1.11 in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from pyvis==0.3.1) (2.6.3)
# Requirement already satisfied: ipython>=5.3.0 in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from pyvis==0.3.1) (8.5.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from pyvis==0.3.1) (3.0.1)
# Requirement already satisfied: pexpect>4.3 in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (4.8.0)
# Requirement already satisfied: decorator in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (5.4.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (3.0.31)
# Requirement already satisfied: jedi>=0.16 in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.18.1)
# Requirement already satisfied: pickleshare in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.7.5)
# Requirement already satisfied: stack-data in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.5.1)
# Requirement already satisfied: backcall in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (2.13.0)
# Requirement already satisfied: matplotlib-inline in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from jinja2>=2.9.6->pyvis==0.3.1) (2.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis==0.3.1) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis==0.3.1) (0.7.0)
# Requirement already satisfied: wcwidth in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=5.3.0->pyvis==0.3.1) (0.2.5)
# Requirement already satisfied: pure-eval in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1) (0.2.2)
# Requirement already satisfied: asttokens in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1) (2.0.8)
# Requirement already satisfied: executing in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1) (1.1.0)
# Requirement already satisfied: six in /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages (from asttokens->stack-data->ipython>=5.3.0->pyvis==0.3.1) (1.16.0)
# Building wheels for collected packages: pyvis
#   Building wheel for pyvis (setup.py) ... done
#   Created wheel for pyvis: filename=pyvis-0.3.1-py3-none-any.whl size=755851 sha256=bdaecea602bd7805bb24685a85835d9f126d3bb7313420209c8a520152f3f735
#   Stored in directory: /mnt/qb/home/mlcolab/hzhou52/.cache/pip/wheels/55/7b/4b/dc896cf96ad07e0dc92d30e1984ab583c0d0feec208756e2b2
# Successfully built pyvis
# Installing collected packages: pyvis
#   Attempting uninstall: pyvis
#     Found existing installation: pyvis 0.3.2
#     Uninstalling pyvis-0.3.2:
#       Successfully uninstalled pyvis-0.3.2
# Successfully installed pyvis-0.3.1

# %% [markdown]
# # 1. statistics overview

# %%
bath_path = '/mnt/qb/work/mlcolab/hzhou52/kt/junyi15/'

# exercise 837, topic 41, area 9
exercise = pd.read_csv(bath_path+'junyi_Exercise_table.csv', encoding = "utf-8",low_memory=False) 
relation = pd.read_csv(bath_path+'relationship_annotation_training.csv', encoding = "utf-8",low_memory=False)
original_log = pd.read_csv(bath_path+'junyi_ProblemLog_original.csv', encoding = "utf-8",low_memory=False)

# %%
original_log.head()
# Out:
#    user_id             exercise   problem_type  problem_number  topic_mode  \
# 0    12884     time_terminology    analog_word               1       False
# 1   239464     multiplication_1              0               6       False
# 2   147359  adding_decimals_0.5              0               6       False
# 3   158155     multiplication_1              0               3       False
# 4   147151        subtraction_2  subtraction-2              10        True
#
#    suggested  review_mode         time_done  time_taken time_taken_attempts  \
# 0      False        False  1420714810324490           4                 3&1
# 1      False        False  1403098400836660           2                   2
# 2      False        False  1418890695540340          16                  16
# 3      False        False  1400469444264040           2                   2
# 4       True        False  1382650905730160           4                   4
#
#    correct  count_attempts  hint_used  count_hints hint_time_taken_list  \
# 0    False               2      False            0                  NaN
# 1     True               1      False            0                  NaN
# 2     True               1      False            0                  NaN
# 3     True               1      False            0                  NaN
# 4     True               1      False            0                  NaN
#
#    earned_proficiency  points_earned
# 0               False              0
# 1               False             14
# 2               False             75
# 3               False             75
# 4               False            225

# %%
log = original_log
print('The columns of log are ', log.columns)
print('The length of log is {}'.format(len(log)))

print('###########################################')

print(count_unique(log, log.columns))
# Out:
# The columns of log are  Index(['user_id', 'exercise', 'problem_type', 'problem_number', 'topic_mode',
#        'suggested', 'review_mode', 'time_done', 'time_taken',
#        'time_taken_attempts', 'correct', 'count_attempts', 'hint_used',
#        'count_hints', 'hint_time_taken_list', 'earned_proficiency',
#        'points_earned'],
#       dtype='object')
# The length of log is 25925992
# ###########################################
# Number of unique values in user_id: 247606
# Number of unique values in exercise: 722
# Number of unique values in problem_type: 1194
# Number of unique values in problem_number: 5174
# Number of unique values in topic_mode: 2
# Number of unique values in suggested: 2
# Number of unique values in review_mode: 2
# Number of unique values in time_done: 25924214
# Number of unique values in time_taken: 7903
# Number of unique values in time_taken_attempts: 821840
# Number of unique values in correct: 2
# Number of unique values in count_attempts: 386
# Number of unique values in hint_used: 2
# Number of unique values in count_hints: 21
# Number of unique values in hint_time_taken_list: 372526
# Number of unique values in earned_proficiency: 2
# Number of unique values in points_earned: 41
# None

# %%
check_nan(log)
# Out:
# Number of NaN values in column user_id: 0
# Number of NaN values in column exercise: 0
# Number of NaN values in column problem_type: 0
# Number of NaN values in column problem_number: 0
# Number of NaN values in column topic_mode: 0
# Number of NaN values in column suggested: 0
# Number of NaN values in column review_mode: 0
# Number of NaN values in column time_done: 0
# Number of NaN values in column time_taken: 0
# Number of NaN values in column time_taken_attempts: 62365
# Number of NaN values in column correct: 0
# Number of NaN values in column count_attempts: 0
# Number of NaN values in column hint_used: 0
# Number of NaN values in column count_hints: 0
# Number of NaN values in column hint_time_taken_list: 24254263
# Number of NaN values in column earned_proficiency: 0
# Number of NaN values in column points_earned: 0

# %%
exercise.head()
# Out:
#                               name  live               prerequisites  \
# 0             parabola_intuition_1  True  recognizing_conic_sections
# 1                 circles_and_arcs  True                         NaN
# 2               inscribed_angles_3  True          inscribed_angles_2
# 3  solving_quadratics_by_factoring  True     factoring_polynomials_1
# 4             graphing_parabolas_1  True      graphing_parabolas_0.5
#
#    h_position  v_position                  creation_date  \
# 0          47           2   2012-10-11 17:55:24.8056 UTC
# 1          40         -20  2012-10-11 17:55:33.41014 UTC
# 2          44         -22  2012-10-11 17:55:44.11836 UTC
# 3          50          -2  2012-10-11 17:54:59.28029 UTC
# 4          52           0  2012-10-11 17:55:00.48268 UTC
#
#    seconds_per_fast_problem pretty_display_name short_display_name  \
# 0                      13.0             ?物線直覺 1             ?物線直覺1
# 1                      27.0                 圓與弧                圓與弧
# 2                       5.0         圓周角與圓心角換算 3         圓周角與圓心角換算3
# 3                       7.0               因式分解法              因式分解法
# 4                      24.0              畫拋物線 1              畫拋物線1
#
#                        topic      area
# 0             conic-sections   algebra
# 1  area-perimeter-and-volume  geometry
# 2          circle-properties  geometry
# 3                quadtratics   algebra
# 4                quadtratics   algebra

# %%
relation.head()
# Out:
#                           Exercise_A  \
# 0  radius_diameter_and_circumference
# 1  radius_diameter_and_circumference
# 2  radius_diameter_and_circumference
# 3               vertex_of_a_parabola
# 4               vertex_of_a_parabola
#
#                                      Exercise_B  Similarity_avg  \
# 0                    arithmetic_word_problems_1        1.857143
# 1                              parts_of_circles        6.785714
# 2           perimeter_of_squares_and_rectangles        3.571429
# 3  solving_quadratics_by_taking_the_square_root        5.923077
# 4                       completing_the_square_1        5.692308
#
#                 Similarity_raw  Difficulty_avg               Difficulty_raw  \
# 0  1_4_1_1_1_1_2_1_1_1_3_1_3_5        2.857143  4_5_1_1_1_1_7_1_1_4_2_5_2_5
# 1  6_9_6_6_7_8_7_8_8_8_4_6_5_7        2.428571  3_5_1_3_2_1_5_1_1_1_1_2_5_3
# 2  2_6_4_1_1_2_4_4_7_2_3_4_4_6        2.285714  2_5_1_1_1_1_3_2_1_1_5_2_3_4
# 3    6_7_6_7_8_4_5_4_3_6_6_8_7        3.307692    3_3_3_1_2_2_4_4_4_3_5_5_4
# 4    7_5_7_8_3_4_5_5_3_6_7_7_7        3.307692    2_3_3_4_2_2_4_4_5_3_4_4_3
#
#    Prerequisite_avg             Prerequisite_raw
# 0          3.000000  1_6_1_1_1_3_2_1_9_2_3_2_8_2
# 1          7.285714  6_7_7_6_8_8_9_5_9_9_7_7_5_9
# 2          5.000000  2_6_5_4_2_8_3_5_9_5_5_3_7_6
# 3          5.846154    5_8_7_7_6_2_6_5_6_7_3_7_7
# 4          5.461538    6_4_6_8_2_2_5_6_5_6_7_7_7

# %%
interested_col = [
    'user_id', 'exercise', 'problem_number', 'time_done', 'time_taken', 'correct', 
]
invert_col = [
    'user_id', 'skill_id', 'problem_id', 'timestamp', 'dwell_time', 'correct', 
]

skill_index = 'exercise'
user_index = 'user_id'

# %%
log['correct'].mean()
# Out:
# 0.8278744358171521

# %% [markdown]
# # 2. remove learner logs with threshold

# %%
remove_thres = [50, 100, 150, 200]

log = original_log
for thres in remove_thres:
    print('remove threshold is {}'.format(thres))
    log = log[~log[skill_index].isna()]
    log = remove_log(log, user_index, num=thres)
    count_unique(log, [user_index, skill_index])
    print(len(log),'/',log[user_index].nunique(),'/',log[skill_index].nunique())
# Out:
# remove threshold is 50
# Number of unique values in user_id: 62124
# Number of unique values in exercise: 721
# 23907121 / 62124 / 721
# remove threshold is 100
# Number of unique values in user_id: 41933
# Number of unique values in exercise: 721
# 22475124 / 41933 / 721
# remove threshold is 150
# Number of unique values in user_id: 32384
# Number of unique values in exercise: 721
# 21306869 / 32384 / 721
# remove threshold is 200
# Number of unique values in user_id: 26629
# Number of unique values in exercise: 721
# 20314363 / 26629 / 721

# %% [markdown]
# ## 2.1 find exercise id in exercise table

# %%
# exercise-id re-match
num_ex = len(exercise)

ex_new_id = pd.DataFrame(columns=['exercise_name', 'exercise_id', 'prerequisite_name', 'prerequisite_id'])
ex_new_id['exercise_name'] = exercise.name
ex_new_id['exercise_id'] = np.arange(len(exercise))
ex_new_id['prerequisite_name'] = exercise.prerequisites

for i in range(len(ex_new_id.prerequisite_name)):
    pre = ex_new_id['prerequisite_name'][i]
    ind = exercise.loc[exercise.name == pre].index
    if len(ind) == 0:
        ex_new_id.prerequisite_id[i] = np.nan
    else:
        ex_new_id.prerequisite_id[i] = ind[0]

# %%
log = original_log
for thres in remove_thres:
    print(f'Remove threshold is {thres}')

    # log = log[~log[skill_index.isna()]]
    log = remove_log(log, user_index, num=thres)

    # Create new DataFrame with desired columns
    df = log[interested_col].copy()
    df.columns = invert_col
    
    # Re-index columns
    skill_dict = dict(zip(ex_new_id.exercise_name, ex_new_id.exercise_id))
    df['skill_id'] = df['skill_id'].apply(lambda x: skill_dict[x])
    df['problem_id'] = pd.Categorical(df['problem_id'], categories=df['problem_id'].unique()).codes
    df['user_id'] = pd.Categorical(df['user_id'], categories=df['user_id'].unique()).codes
    df = df.astype({'timestamp': np.float64, 'correct': np.float64})
    df = df.astype({'user_id': np.int64, 'skill_id': np.int64})
    
    # Save cleaned DataFrame to a CSV file
    df.to_csv(f'/mnt/qb/work/mlcolab/hzhou52/kt/junyi15/multi_skill/interactions_{thres}.csv', sep='\t', index=False)

    print(f'Remove threshold {thres} is done!')
    print(count_unique(df, df.columns.tolist()))
    print(f'Length of DataFrame: {len(df)}')
# Out:
# Remove threshold is 50
# Remove threshold 50 is done!
# Number of unique values in user_id: 62124
# Number of unique values in skill_id: 721
# Number of unique values in problem_id: 5174
# Number of unique values in timestamp: 23905466
# Number of unique values in dwell_time: 7197
# Number of unique values in correct: 2
# None
# Length of DataFrame: 23907121
# Remove threshold is 100
# Remove threshold 100 is done!
# Number of unique values in user_id: 41933
# Number of unique values in skill_id: 721
# Number of unique values in problem_id: 5174
# Number of unique values in timestamp: 22473616
# Number of unique values in dwell_time: 6970
# Number of unique values in correct: 2
# None
# Length of DataFrame: 22475124
# Remove threshold is 150
# Remove threshold 150 is done!
# Number of unique values in user_id: 32384
# Number of unique values in skill_id: 721
# Number of unique values in problem_id: 5174
# Number of unique values in timestamp: 21305436
# Number of unique values in dwell_time: 6785
# Number of unique values in correct: 2
# None
# Length of DataFrame: 21306869
# Remove threshold is 200
# Remove threshold 200 is done!
# Number of unique values in user_id: 26629
# Number of unique values in skill_id: 721
# Number of unique values in problem_id: 5174
# Number of unique values in timestamp: 20312955
# Number of unique values in dwell_time: 6634
# Number of unique values in correct: 2
# None
# Length of DataFrame: 20314363

# %%
df
# Out:
#           user_id  skill_id  problem_id     timestamp  dwell_time  correct
# 0               0        69           0  1.420715e+15           4      0.0
# 4               1       433           1  1.382651e+15           4      1.0
# 6               2       778           0  1.395367e+15          19      0.0
# 8               3       666           2  1.395809e+15           4      1.0
# 9               4       440           3  1.394098e+15           2      1.0
# ...           ...       ...         ...           ...         ...      ...
# 25925987    12565       763           4  1.377638e+15           7      1.0
# 25925988    20753       316           6  1.402971e+15          34      1.0
# 25925989    21092        51          80  1.397029e+15          18      1.0
# 25925990    11805       681          19  1.396568e+15           2      1.0
# 25925991    21332       433           6  1.396339e+15           4      1.0
#
# [20314363 rows x 6 columns]

# %% [markdown]
# # 3. extract single learner

# %%
remove_thres = [50, 100, 150, 200]

log = original_log

users = []
users_log = log.groupby([user_index, skill_index]).size().reset_index(name='count')

for thres in remove_thres:
    users.append(users_log[users_log['count']>thres])

# %%
interested_col = [
    'user_id', 'exercise', 'problem_number', 'time_done', 'time_taken', 'correct', 
]
invert_col = [
    'user_id', 'skill_id', 'problem_id', 'timestamp', 'dwell_time', 'correct', 
]

skill_index = 'exercise'
user_index = 'user_id'

# %%
from tqdm import tqdm

log = original_log
useful_log = log[interested_col]
remove_thres = [50, 100, 150, 200]

users_logs_threshold = []
for thres in remove_thres:
    print('With threshold {} there are {} logs'.format(thres, len(useful_log)))
    grouped_data = useful_log.groupby([user_index, skill_index])
    sk_dfs = grouped_data.apply(lambda x: x.sort_values('time_done')[:thres])
    users_logs_threshold.append([df for _, df in sk_dfs.groupby([user_index, skill_index])])
# Out:
# With threshold 50 there are 25925992 logs
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [14], line 12
#      10 grouped_data = useful_log.groupby([user_index, skill_index])
#      11 sk_dfs = grouped_data.apply(lambda x: x.sort_values('time_done')[:thres])
# ---> 12 users_logs_threshold.append([df for _, df in sk_dfs.groupby([user_index, skill_index])])
#
# File /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages/pandas/core/frame.py:7718, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7713 axis = self._get_axis_number(axis)
#    7715 # https://github.com/python/mypy/issues/7642
#    7716 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7717 # "Union[bool, NoDefault]"; expected "bool"
# -> 7718 return DataFrameGroupBy(
#    7719     obj=self,
#    7720     keys=by,
#    7721     axis=axis,
#    7722     level=level,
#    7723     as_index=as_index,
#    7724     sort=sort,
#    7725     group_keys=group_keys,
#    7726     squeeze=squeeze,  # type: ignore[arg-type]
#    7727     observed=observed,
#    7728     dropna=dropna,
#    7729 )
#
# File /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages/pandas/core/groupby/grouper.py:872, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     870 if gpr in obj:
#     871     if validate:
# --> 872         obj._check_label_or_level_ambiguity(gpr, axis=axis)
#     873     in_axis, name, gpr = True, gpr, obj[gpr]
#     874     if gpr.ndim != 1:
#     875         # non-unique columns; raise here to get the name in the
#     876         # exception message
#
# File /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages/pandas/core/generic.py:1794, in NDFrame._check_label_or_level_ambiguity(self, key, axis)
#    1786 label_article, label_type = (
#    1787     ("a", "column") if axis == 0 else ("an", "index")
#    1788 )
#    1790 msg = (
#    1791     f"'{key}' is both {level_article} {level_type} level and "
#    1792     f"{label_article} {label_type} label, which is ambiguous."
#    1793 )
# -> 1794 raise ValueError(msg)
#
# ValueError: 'user_id' is both an index level and a column label, which is ambiguous.

# %%
######################################## single_user_single_exercise
from tqdm import tqdm
log = original_log
useful_log = log[interested_col]
remove_thres = [50, 100, 150, 200]

users_logs_threshold = []
for i in range(len(remove_thres)):
    thres = remove_thres[i]
    users_with_threshold = users[i]
    
    single_skill = {col: [] for col in interested_col}

    sk_dfs = []
    print('With threshold {} there are {} logs'.format(thres, len(users_with_threshold)))
    for j in tqdm(range(len(users_with_threshold))):
        id = users_with_threshold[user_index].iloc[j]
        ex = users_with_threshold[skill_index].iloc[j]

        single_user_exercise = useful_log.loc[(useful_log[user_index] == id) & (useful_log[skill_index] == ex)]
        single_user_exercise = single_user_exercise.sort_values('time_done')[:thres]

        sk_dfs.append(single_user_exercise)
    users_logs_threshold.append(sk_dfs)
# Out:
# With threshold 50 there are 55086 logs
#  32%|███▏      | 17507/55086 [5:41:39<12:13:22,  1.17s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [15], line 20
#      17 id = users_with_threshold[user_index].iloc[j]
#      18 ex = users_with_threshold[skill_index].iloc[j]
# ---> 20 single_user_exercise = useful_log.loc[(useful_log[user_index] == id) & (useful_log[skill_index] == ex)]
#      21 single_user_exercise = single_user_exercise.sort_values('time_done')[:thres]
#      23 sk_dfs.append(single_user_exercise)
#
# File /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages/pandas/core/series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# -> 5623     res_values = ops.comparison_op(lvalues, rvalues, op)
#    5625 return self._construct_result(res_values, name=res_name)
#
# File /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:283, in comparison_op(left, right, op)
#     280     return invalid_comparison(lvalues, rvalues, op)
#     282 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 283     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285 else:
#     286     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File /mnt/qb/work/mlcolab/hzhou52/anaconda3/envs/mykt/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:73, in comp_method_OBJECT_ARRAY(op, x, y)
#      71     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72 else:
# ---> 73     result = libops.scalar_compare(x.ravel(), y, op)
#      74 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %% [markdown]
# # find ground-truth knowledge graph

# %%
# exercise-id re-match
base_pth = '/mnt/qb/work/mlcolab/hzhou52/kt/junyi15/'

exercise = pd.read_csv(base_pth+'junyi_Exercise_table.csv', encoding = "utf-8",low_memory=False) 

num_ex = len(exercise)

ex_new_id = pd.DataFrame(columns=['exercise_name', 'exercise_id', 'prerequisite_name', 'prerequisite_id'])
ex_new_id['exercise_name'] = exercise.name
ex_new_id['exercise_id'] = np.arange(len(exercise))
ex_new_id['prerequisite_name'] = exercise.prerequisites
ex_new_id['topic'] = exercise.topic
ex_new_id['area'] = exercise.area

for i in range(len(ex_new_id.prerequisite_name)):
    pre = ex_new_id['prerequisite_name'][i]
    ind = exercise.loc[exercise.name == pre].index
    if len(ind) == 0:
        ex_new_id.prerequisite_id[i] = np.nan
    else:
        ex_new_id.prerequisite_id[i] = ind[0]

# %%
ex_new_id.head()
# Out:
#                      exercise_name  exercise_id           prerequisite_name  \
# 0             parabola_intuition_1            0  recognizing_conic_sections
# 1                 circles_and_arcs            1                         NaN
# 2               inscribed_angles_3            2          inscribed_angles_2
# 3  solving_quadratics_by_factoring            3     factoring_polynomials_1
# 4             graphing_parabolas_1            4      graphing_parabolas_0.5
#
#   prerequisite_id                      topic      area
# 0             524             conic-sections   algebra
# 1             NaN  area-perimeter-and-volume  geometry
# 2             331          circle-properties  geometry
# 3             673                quadtratics   algebra
# 4             330                quadtratics   algebra

# %%
check_nan(ex_new_id)
# Out:
# Number of NaN values in column exercise_name: 0
# Number of NaN values in column exercise_id: 0
# Number of NaN values in column prerequisite_name: 95
# Number of NaN values in column prerequisite_id: 284
# Number of NaN values in column topic: 20
# Number of NaN values in column area: 20

# %% [markdown]
# # statistics check

# %%
df = df.astype({
    'timestamp': np.float64,
    'dwell_time': np.float64,
    'correct': np.float64,
    'problem_id': np.int64,
    'skill_id': np.int64
    })

# %%
# Save
remove_thres = 800
df.to_csv(bath_path+'interactions_{}.csv'.format(remove_thres), sep='\t', index=False)

# %%
count_unique(df, list(df.columns))
len(df)
# Out:
# number of unique value in user_id: 26629
# number of unique value in problem_id: 721
# number of unique value in skill_id: 721
# number of unique value in timestamp: 20312955
# number of unique value in dwell_time: 6634
# number of unique value in correct: 2
# number of unique value in skill_name: 721
# 20314363
