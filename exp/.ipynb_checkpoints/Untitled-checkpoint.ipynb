# %%
import sys
sys.path.append('..')

import math
import random

import torch
import torch.nn as nn
from collections import defaultdict

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# from models.parametric_models import VanillaOU

# %%
######################################## load data 
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
from collections import defaultdict
import operator

bath_path = '/mnt/qb/work/mlcolab/hzhou52/kt/junyi/'

# exercise 837, topic 41, area 9
# exercise = pd.read_csv(bath_path+'junyi_Exercise_table.csv', encoding = "utf-8",low_memory=False) 
# relation = pd.read_csv(bath_path+'relationship_annotation_training.csv', encoding = "utf-8",low_memory=False)
log = pd.read_csv(bath_path+'junyi_ProblemLog_original.csv', encoding = "utf-8",low_memory=False)

# log.head()
users = log.groupby(['user_id', 'exercise']).size().reset_index(name='count')
users = users.sort_values('count')

users[users['count']>100]

# the following needs to come from the above filter
data = log.loc[(log.user_id == 66633) & (log.exercise == 'number_properties_terminology_1')]
data = data.sort_values('time_done')

t_data = np.array(data['time_done'].values) # .reshape(1, -1)
x_data = np.array(data['correct'].values*1) # .reshape(1, -1)*1

# %%
######################################## to test the simulate_path in the class
num_seq = 1
num_node = 1
speed = torch.tensor(0.02, device=device)
mean = torch.tensor(0.63, device=device)
noise = torch.tensor(0.0001, device=device)

x0 = torch.zeros((num_seq, num_node), device=device)
time = torch.tensor(t_data.reshape(num_node, -1)).to(device)

t_data = torch.tensor(t_data.reshape(num_seq, -1), device=device)
x_data = torch.tensor(x_data.reshape(num_seq, -1), device=device)

model = VanillaOU(speed, mean, noise, mode='train', device=device)
# x = model.simulate_path(x0, t=time)

# %%
######################################## rescale time data
log_t = []
dt = torch.log(torch.diff(t_data))
log_t.append(torch.zeros_like(dt[:,0]))
for i in range(0, dt.shape[-1]):
    log_t.append(log_t[-1] + dt[:, i])
log_t = torch.stack(log_t, -1)

# %%
######################################## train based on hand-crafted MLE
num_seq = 1
num_node = 1
model = VanillaOU(mode='train', device=device)

t_data = torch.tensor(t_data.reshape(num_seq, -1), device=device)
x_data = torch.tensor(x_data.reshape(num_seq, -1), device=device)

x0 = x_data[:, 0]
time_step = x_data.shape[-1]
# for i in range(time_step):
    
#     x0 = x_data[:, i]
# Out:
# /scratch_local/hzhou52-2981022/tmp/ipykernel_152127/600469873.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   t_data = torch.tensor(t_data.reshape(num_seq, -1), device=device)
# /scratch_local/hzhou52-2981022/tmp/ipykernel_152127/600469873.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_data = torch.tensor(x_data.reshape(num_seq, -1), device=device)

# %%
llsum
# Out:
# tensor([nan], device='cuda:0', dtype=torch.float64)

# %%
import numpy as np
time_step = x_data.shape[-1]
llsum=0
i=0
estimator = OrnsteinUhlenbeckEstimator([(log_t.cpu().numpy()[0,i:i+10], x_data.cpu().numpy()[0, i:i+10])], n_it=1)
model = VanillaOU(mode='train', device=device)

for i in range(time_step-10):
    print('epoch {}'.format(i))
    ite = estimator.iterate([(log_t.cpu().numpy()[0,i:i+3], x_data.cpu().numpy()[0, i:i+3])])
    level = torch.tensor(estimator.mu, device=device)
    speed = torch.tensor(estimator.eta, device=device)
    var = torch.tensor(estimator.sigma_sq(), device=device)
    
    ll = model.logll(x_data[:, i+1:i+3], t_data[:, i:i+3], speed, level, torch.sqrt(var))
    llsum += ll
    
print(f'mu = {estimator.mu}')
print(f'eta = {estimator.eta}')
print(f'sigma^2 = {estimator.sigma_sq()}')
# Out:
# epoch 0
# epoch 1
# epoch 2
# epoch 3
# epoch 4
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# epoch 21
# epoch 22
# epoch 23
# epoch 24
# epoch 25
# epoch 26
# epoch 27
# epoch 28
# epoch 29
# epoch 30
# epoch 31
# epoch 32
# epoch 33
# epoch 34
# epoch 35
# epoch 36
# epoch 37
# epoch 38
# epoch 39
# epoch 40
# epoch 41
# epoch 42
# epoch 43
# epoch 44
# epoch 45
# epoch 46
# epoch 47
# epoch 48
# epoch 49
# epoch 50
# epoch 51
# epoch 52
# epoch 53
# epoch 54
# epoch 55
# epoch 56
# epoch 57
# epoch 58
# epoch 59
# epoch 60
# epoch 61
# epoch 62
# epoch 63
# epoch 64
# epoch 65
# epoch 66
# epoch 67
# epoch 68
# epoch 69
# epoch 70
# epoch 71
# epoch 72
# epoch 73
# epoch 74
# epoch 75
# epoch 76
# epoch 77
# epoch 78
# epoch 79
# epoch 80
# epoch 81
# epoch 82
# epoch 83
# epoch 84
# epoch 85
# epoch 86
# epoch 87
# epoch 88
# epoch 89
# epoch 90
# mu = 0.9999995000000385
# eta = [1.]
# sigma^2 = [4.99999711e-13]

# %%
x0 = x_data[:, 0:1]
x1 = x_data[:, 1:2]
time = t_data[:, 0:2]

# %%
x1_hat = model.simulate_path(x0=x0, t=time)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [85], line 1
# ----> 1 x1_hat = model.simulate_path(x0=x0, t=time)
#
# Cell In [83], line 123, in VanillaOU.simulate_path(self, x0, t, items)
#     121 assert len(t) > 0
#     122 num_seq, time_step = t.shape
# --> 123 num_node = x0.shape[1]
#     125 dt = torch.diff(t).unsqueeze(1)
#     126 dt = torch.tile(dt, (1, num_node, 1)) # [bs, num_node, time-1]
#
# IndexError: tuple index out of range

# %%
ll = model.logll(x=x_data[:, 0:100], t=t_data[:, 0:101])

# %%
learning_rate = 1e-3

for _ in range(10000):
    ll = model.logll(x=x_data[:, 0:2], t=t_data[:, 0:3])
    loss = -ll
    print(loss)
    model.zero_grad()
    loss.backward()
    with torch.no_grad():
        for name, param in model.named_parameters():
            if param.requires_grad == True:
                # print(name, param.clone())
                param -= learning_rate * param.grad
                print(name, param.clone(), param.grad)
                if name == 'mean_rev_speed' or 'vola':
                    # model.mean_rev_speed = torch.sigmoid(param)+1e-3
                    param.data.clamp_(1e-5)
                    # print('111', model.mean_rev_speed)
# Out:
# tensor([-27.6576], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-181973.2656]], device='cuda:0') tensor([[1.8197e+08]], device='cuda:0')
# mean_rev_level tensor([[0.0452]], device='cuda:0') tensor([[-0.4417]], device='cuda:0')
# tensor([-27.6576], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-181957.2656]], device='cuda:0') tensor([[1.8196e+08]], device='cuda:0')
# mean_rev_level tensor([[0.0456]], device='cuda:0') tensor([[-0.4415]], device='cuda:0')
# tensor([-27.6576], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-181941.2656]], device='cuda:0') tensor([[1.8194e+08]], device='cuda:0')
# mean_rev_level tensor([[0.0461]], device='cuda:0') tensor([[-0.4413]], device='cuda:0')
# tensor([-27.6576], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-181925.2656]], device='cuda:0') tensor([[1.8193e+08]], device='cuda:0')
# mean_rev_level tensor([[0.0465]], device='cuda:0') tensor([[-0.4411]], device='cuda:0')
# tensor([-27.6576], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-181909.2656]], device='cuda:0') tensor([[1.8191e+08]], device='cuda:0')
# mean_rev_level tensor([[0.
+08]], device='cuda:0')
# mean_rev_level tensor([[0.1235]], device='cuda:0') tensor([[-0.4055]], device='cuda:0')
# tensor([-27.6545], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-179056.4062]], device='cuda:0') tensor([[1.7906e+08]], device='cuda:0')
# mean_rev_level tensor([[0.1239]], device='cuda:0') tensor([[-0.4053]], device='cuda:0')
# tensor([-27.6545], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-179041.0625]], device='cuda:0') tensor([[1.7904e+08]], device='cuda:0')
# mean_rev_level tensor([[0.1243]], device='cuda:0') tensor([[-0.4051]], device='cuda:0')
# tensor([-27.6545], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-179025.7188]], device='cuda:0') tensor([[1.7903e+08]], device='cuda:0')
# mean_rev_level tensor([[0.1247]], device='cuda:0') tensor([[-0.4049]], device='cuda:0')
# tensor([-27.6545], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-179010.3750]], device='cuda:0') tensor([[1.7901e+08]], device='cuda:0')
# mean_rev_level tensor([[0.1251]], device='cuda:0') tensor([[-0.4047]], device='cuda:0')
# tensor([-27.7556], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-191476.2812]], device='cuda:0') tensor([[1.9148e+08]], device='cuda:0')
# mean_rev_level tensor([[0.1254]], device='cuda:0') tensor([[-0.2889]], device='cuda:0')
# tensor([-27.7556], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-191467.8594]], device='cuda:0') tensor([[1.9147e+08]], device='cuda:0')
# mean_rev_level tensor([[0.1257]], device='cuda:0') tensor([[-0.2888]], device='cuda:0')
# tensor([-27.7556], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-191459.4688]], device='cuda:0') tensor([[1.9146e+08]], device='cuda:0')
# mean_rev_level tensor([[0.1260]], device='cuda:0') tensor([[-0.2887]], device='cuda:0')
# tensor([-27.7556], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-191451.0781]], device='cuda:0') tensor([[1.9145e+08]], device='cuda:0')
# mean_rev_level tensor([[0.1263]], device='cuda:0') tensor([[-0.2885]], device='cuda:0')
# tensor([-27.7555], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-191442.7031]], device='cuda:0') tensor([[1.9144e+08]], device='cuda:0')
# mean_rev_level tensor([[0.1266]], device='cuda:0') tensor([[-0.2884]], device='cuda:0')
# tensor([-27.7555], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-191434.3281]], device='cuda:0') tensor([[1.9143e+08]], device='cuda:0')
# ...
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.6719]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.6406]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.6250]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.5938]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.5625]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.5156]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.5000]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.4531]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.4531]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.4062]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.3906]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.3750]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.3281]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.3125]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.2500]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.2344]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.2031]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.1875]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.1562]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.1250]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.0938]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.0625]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.0469]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189225.0156]], device='cuda:0') tensor([[1.8923e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0011]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.9688]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.9375]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.9219]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.8906]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.8594]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.8281]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.7969]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.7812]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.7344]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.7188]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.6875]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.6719]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.6094]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.5938]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.5469]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.5312]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.4844]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.4688]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.4375]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4977]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.4062]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.3906]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.3438]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.3281]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.2969]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.2656]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.2188]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.2031]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.2031]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.1562]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.1406]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.0938]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.0938]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.0625]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.0312]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189224.0156]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189223.9688]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189223.9219]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189223.8906]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189223.8750]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189223.8281]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')
# tensor([-27.7742], device='cuda:0', grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[-189223.8125]], device='cuda:0') tensor([[1.8922e+08]], device='cuda:0')
# mean_rev_level tensor([[0.4978]], device='cuda:0') tensor([[-0.0010]], device='cuda:0')

# %%
x_data.shape
# Out:
# (101,)

# %%
learning_rate = 1e-3
train_step = 100000
model = VanillaOU(mode='train', device=device).double()

for t in range(train_step):
    
    logll = model.logll(x=x_data[..., 1:], t=t_data)
    loss = -logll
    #x0 = torch.zeros((1,1), device=device)
    #path = model.simulate_path(x0=x0, t=t_data)
    #torch.sigmoid(path.flatten())
    #bce = nn.BCELoss()
    #loss = bce(torch.sigmoid(path.flatten()), x_data.double().flatten()[1:])
    
    
    model.zero_grad()

    loss.backward()

    with torch.no_grad():
        for name, param in model.named_parameters():
            if param.requires_grad == True:
                param -= learning_rate * param.grad
                # print(param.grad)
                if t % 1000 == 0:
                    print(name, param.clone(), param.grad.clone())
                if name == 'mean_rev_speed' or 'vola':
                    # model.mean_rev_speed = torch.sigmoid(param)+1e-3
                    param.data.clamp_(1e-8)
                    # print('111', model.mean_rev_speed)
    if t % 1000 == 0:
        print('loss: ', loss)
# Out:
# mean_rev_speed tensor([[0.5606]], device='cuda:0', dtype=torch.float64) tensor([[-201.6938]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.2045]], device='cuda:0', dtype=torch.float64) tensor([[-28.0340]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.8012]], device='cuda:0', dtype=torch.float64) tensor([[152.7801]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([129.1924], device='cuda:0', dtype=torch.float64,
#        grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5795]], device='cuda:0', dtype=torch.float64) tensor([[-17.6432]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0007]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7298]], device='cuda:0', dtype=torch.float64) tensor([[26.4467]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.3369], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5870]], device='cuda:0', dtype=torch.float64) tensor([[-3.6068]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0001]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7489]], device='cuda:0', dtype=torch.float64) tensor([[5.7588]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.0840], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5872]], device='cuda:0', dtype=torch.float64) tensor([[-7.2203]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7452]], device='cuda:0', dtype=torch.float64) tensor([[11.2575]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1182], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5886]], device='cuda:0', dtype=torch.float64) tensor([[-8.3488]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7450]], device='cuda:0', dtype=torch.float64) tensor([[12.9670]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1340], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.8547]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7455]], device='cuda:0', dtype=torch.float64) tensor([[12.2231]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1270], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5884]], device='cuda:0', dtype=torch.float64) tensor([[-7.8782]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.2577]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1273], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.9152]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.3137]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1278], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.9046]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.2978]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1277], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.9039]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.2966]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1276], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.9050]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.2983]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1277], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.9048]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.2980]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1277], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.9047]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.2979]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1277], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.9048]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.2980]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1277], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.9048]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.2980]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1277], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.9048]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.2980]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1277], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.9048]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.2980]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1277], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.9048]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.2980]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1277], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.9048]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.2980]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1277], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# mean_rev_speed tensor([[0.5885]], device='cuda:0', dtype=torch.float64) tensor([[-7.9048]], device='cuda:0', dtype=torch.float64)
# mean_rev_level tensor([[0.6300]], device='cuda:0', dtype=torch.float64) tensor([[0.0003]], device='cuda:0', dtype=torch.float64)
# vola tensor([[0.7454]], device='cuda:0', dtype=torch.float64) tensor([[12.2980]], device='cuda:0', dtype=torch.float64)
# loss:  tensor([69.1277], device='cuda:0', dtype=torch.float64, grad_fn=<NegBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [77], line 7
#       3 model = VanillaOU(mode='train', device=device).double()
#       5 for t in range(train_step):
# ----> 7     logll = model.logll(x=x_data[..., 1:], t=t_data)
#       8     loss = -logll
#       9     #x0 = torch.zeros((1,1), device=device)
#      10     #path = model.simulate_path(x0=x0, t=t_data)
#      11     #torch.sigmoid(path.flatten())
#      12     #bce = nn.BCELoss()
#      13     #loss = bce(torch.sigmoid(path.flatten()), x_data.double().flatten()[1:])
#
# Cell In [44], line 96, in VanillaOU.logll(self, x, t, speed, level, vola)
#      94 dt = torch.diff(t)
#      95 dt = torch.log(dt) # TODO
# ---> 96 mu = self.mean(x, dt, speed, level)
#      97 sigma = self.std(dt, speed, vola)
#      98 var = self.variance(dt, speed, vola)
#
# Cell In [44], line 79, in VanillaOU.mean(self, x0, t, speed, level)
#      77 speed = speed if speed is not None else self.mean_rev_speed
#      78 level = level if level is not None else self.mean_rev_level
# ---> 79 return x0 * torch.exp(-speed * t) + (1.0 - torch.exp(- speed * t)) * level
#
# KeyboardInterrupt:

# %%
# test different results
model = VanillaOU(mode='train', device=device)

mlespeed = torch.tensor(0.5255, device=device)
mlelevel = torch.tensor(0.6298, device=device)
mlevola = torch.tensor(0.4950, device=device)

bcespeed = torch.tensor(0.4962, device=device)
bcelevel = torch.tensor(0.5321, device=device)
bcevola = torch.tensor(0.0012, device=device)

mu = torch.tensor(0.63, device=device)
eta = torch.tensor(1.67261056e-05, device=device)
sigma = torch.tensor(7.79771041e-06, device=device)

log3 = model.logll(x=x_data[..., 1:], t=t_data, speed=eta, level=mu, vola=torch.sqrt(sigma))
log2 = model.logll(x=x_data[..., 1:], t=t_data, speed=bcespeed, level=bcelevel, vola=bcevola)
log1 = model.logll(x=x_data[..., 1:], t=t_data, speed=mlespeed, level=mlelevel, vola=mlevola)

print('estimation from existing ou estimator: ', log3)

# %%
model = VanillaOU(mlespeed, mlelevel, mlevola, mode='synthetic', device=device)

x0 = torch.zeros((num_seq, num_node, 1), device=device)
x = model.simulate_path(x0, t=t_data)

# %%
def likelihood(
    t, x, eta: float, mu: float = 0.0, variance=0.0
) -> float:
    """
    Returns the likelihood where sigma^2 has been replace by its MLE estimator
    as a function of eta and mu. It diverges if eta == 0.
    - (n/2) * (1 + log D) - (1/2) * sum log [1 - exp(-2*eta*dt)]
    """
    dt = t[1:] - t[:-1]
    nm1 = dt.size
    dev = variance

    return (
        -0.5 * nm1 * (1.0 + np.log(2.0 * np.pi * dev))
        - 0.5 * np.log(-np.expm1(-2.0 * eta * dt)).sum()
    )

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import numpy as np
import networkx as nx
import os
import imageio
import ipdb

def sigmoid(x):
  return 1 / (1 + np.exp(-x))

path = x.cpu().numpy()
times = t_data.cpu().numpy()
times = np.diff(times)
times = np.log(times)
scale = []
scale.append(times[0,0])
for i in range(1, times.shape[-1]):
    scale.append(scale[-1]+times[0,i])

plt.clf()

color = cm.rainbow(np.linspace(0, 1, num_node))
plt.figure(figsize=(20,8))
plt.xlabel('time t')
plt.ylabel('recall_probability')
plt.title(label='OU Model',
        fontsize=20,
        color="black")

plt.plot(scale, path[0,0,0], color='red', linewidth=4)
plt.scatter(scale, x_data[...,1:].cpu().numpy(), s=10)

# plt.legend()

# %%
######################################## to test whether the distribution has gradient
loc = torch.rand((2,2), device=device)
loc = nn.Parameter(loc, requires_grad=True)

scale = torch.rand((2,2), device=device)
scale = nn.Parameter(scale, requires_grad=True)

distr = torch.distributions.normal.Normal(loc, scale, validate_args=None)
x = torch.tensor([(0.1,0.1),(0.1,0.1)], device=device)

# %%
# Out:
# /scratch_local/hzhou52-2957465/tmp/ipykernel_35464/3662424423.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   time = torch.tensor(t_data.reshape(num_node, -1)).to(device)

# %%
import numpy as np
estimator = OrnsteinUhlenbeckEstimator([(t_data.cpu().numpy()[0, :3], x_data.cpu().numpy()[0, :3])], n_it=1500)

print(f'mu = {estimator.mu}')
print(f'eta = {estimator.eta}')
print(f'sigma^2 = {estimator.sigma_sq()}')
# Out:
# mu = 0.5
# eta = [5.57790132e-06]
# sigma^2 = [2.78895066e-06]

# %%
import os
from torch import optim, nn, utils, Tensor
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
import pytorch_lightning as pl

# Training arguments
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = 'cpu'
batch_size = 32
epoch = 200
num_seq = 1

# add statistics
times = first.time_done.values.reshape(num_seq, -1)
corrects = first.correct.values.reshape(num_seq, -1)
num_total = np.arange(times.shape[-1])
success = 0
num_success = []
for i in range(times.shape[-1]):
    if corrects[:, i] == 1:
        success += 1
    num_success.append(success)
num_failure = num_total-num_success

stats = np.stack([num_total, num_success, num_failure], -1).reshape(num_seq, -1, 3)

# setup tensor data
data = [times, corrects, stats]
tensor_data = [torch.tensor(t*1, device=device) for t in data]

# tensor_data:
## times: [num_seq, t]
## labels: [num_seq, t]
## stats: [num_seq, t, 3]

train_loader = utils.data.DataLoader(tensor_data, batch_size=batch_size, shuffle=False)

# %%
first = log.loc[(log.user_id == 88703) & (log.exercise == 'telling_time_comparing')]
second = log.loc[(log.user_id == 88703) & (log.exercise == 'time_units_transformation_1')]
third = log.loc[(log.user_id == 52504) & (log.exercise == 'radical_equations')]
first = first.sort_values('time_done')

# %%
from typing import List, Tuple, Optional
import logging
import numpy as np
from nptyping import NDArray
import scipy.optimize as opt

class OrnsteinUhlenbeckEstimator:
    """
    Convenience class to evaluate the Ornstein-Uhlenbeck parameters of multiple
    sets of series.
    """

    def __init__(self, data, **kwargs):
        """
        Initialize the class.
        data: List of tuples of (t, x) arrays
        kwargs:
          n_it: number of iterations to take (default 1)
          init_mu: starting parameter for mu (default is mean of data)
          init_eta: starting parameter for eta (default is a very rough guess)
        """
        self.data = data
        
        n_iter = kwargs.pop("n_it", 1)
        self.n_iter = n_iter
        if n_iter <= 0:
            logging.warning(
                "Parameter estimates will not be accurate without at least one iteration."
            )
        # for t, x in data:
        #     if t.size != x.shape[0]:
        #         raise RuntimeError("Time and signal data must have the same length.")
        #     if t.size < 1:
        #         raise RuntimeError("Not enough data points in a set.")
        
        # The effective number is one less than the length because it is the
        # adjacent differences that are used.
        self.ns = [ts.size - 1 for ts, _ in data]
        self.mu = kwargs.pop(
            "init_mu", sum([np.sum(x) for (_, x) in data]) / sum(self.ns)
        )
        self.eta = kwargs.pop(
            "init_eta", np.average([eta_start(*tx) for tx in data], weights=self.ns),
        )
        if kwargs:
            logging.error("Unrecognized keyword arguments: {kwargs.keys()}")
            raise RuntimeError("Unrecognized keyword arguments")
    


    def iterate(self, data) -> None:
        """
        Do an iteration on eta then mu, using MLE for eta (at constant mu) then
        updating mu exactly.
        """
        n = self.n_iter
        
        while n > 0:
            def func(eta: float) -> float:
                return -2.0 * np.sum([likelihood(t, x, eta, self.mu) for t, x in data])

            def grad(eta: float) -> float:
                return np.array(
                    np.sum(
                        [-2.0 * deta_likelihood(t, x, eta, self.mu) for t, x in data],
                    )
                )

            # The bounds should be configurable; in principle eta can be > 1.0
            fit = opt.minimize(func, self.eta, jac=grad, bounds=[(0.0, 1.0)])
            if not fit.success:
                print("Error: fit was not successful.")
                raise RuntimeError(fit.message)
            self.eta = fit.x
            # eta_err = np.sqrt(2.0 * fit.hess_inv * np.eye(1))
            # print(f"eta err = {eta_err}")
            
            self.mu = mu_list(data, self.eta)

            n -= 1
        # The *average* variance (not the point-by-point expected variance)
        self.variance = np.average(
            [variance(t, x, self.eta, self.mu) for t, x in data], weights=self.ns
        )
        
        
        
        
    def sigma_sq(self) -> float:
        """
        Return the sigma-squared parameter (the variance per small change in
        time) given the current estimates.
        """
        return 2.0 * self.eta * self.variance

    def deviations(
        self, data=None
    ):
        """
        Returns the weighted deviations at each point.
        """
        the_data = data or self.data
        return np.concatenate(
            [deviations(t, x, self.eta, self.mu) for t, x in the_data]
        )


def eta_start(t, x) -> float:
    """
    Returns a guesstimate of eta (totally unverified). This probably only holds
    for equally-spaced steps. But it provides a reasonable start value around an
    order of magnitude from the real one.
    """
    dt = t[1:] - t[:-1]
    dx = x[1:] - x[:-1]
    xdx = (x[:-1] * dx).sum()
    x2dt = (np.square(x[:-1]) * dt).sum()
    eta = -xdx / (x2dt+1e-6) + 1e-6
    assert eta > 0.0, "eta must be positive"
    return eta


def likelihood(
    t, x, eta: float, mu: float = 0.0
) -> float:
    """
    Returns the likelihood where sigma^2 has been replace by its MLE estimator
    as a function of eta and mu. It diverges if eta == 0.
    - (n/2) * (1 + log D) - (1/2) * sum log [1 - exp(-2*eta*dt)]
    """
    dt = t[1:] - t[:-1]
    nm1 = dt.size
    dev = variance(t, x, eta, mu)

    return (
        -0.5 * nm1 * (1.0 + np.log(2.0 * np.pi * dev +1e-6))
        - 0.5 * np.log(-np.expm1(-2.0 * eta * dt)+1e-6).sum()
    )


def deta_likelihood(
    t, x, eta: float, mu: float = 0.0
) -> float:
    """
    The gradient of the total likelihood with respect to eta.
    """
    dt = t[1:] - t[:-1]
    nm1 = dt.size
    dev = variance(t, x, eta, mu)
    deta_dev = deta_variance(t, x, eta, mu)
    exp_2etadt = np.exp(-2 * eta * dt)
    expm1_2etadt = np.expm1(-2 * eta * dt)
    return -0.5 * nm1 * deta_dev / (dev+1e-6) + np.sum(dt * exp_2etadt / expm1_2etadt)


def opt_eta(t, x, mu: float = 0.0) -> float:
    """
    Return the eta parameter estimated by maximum likelihood.
    """
    eta_init = np.array([eta_start(t, x)])

    def func(eta: float) -> float:
        return -2.0 * likelihood(t, x, eta, mu)

    def grad(eta: float) -> float:
        return np.array([-2.0 * deta_likelihood(t, x, eta, mu)])

    fit = opt.minimize(func, eta_init, jac=grad, bounds=[(0.0, 1.0)])
    if not fit.success:
        print("Error: fit was not successful. {fit.message}")
    # eta_err = np.sqrt(2.0 * fit.hess_inv * np.eye(1))
    # print(f"eta err = {eta_err}")
    return fit.x


def deviations(
    t, x, eta: float, mu: float = 0.0
):
    """
    Returns the appropriately-weighted unsigned deviations i.e. the difference
    from predicted divided by the standard deviation.
    """
    # the time (or position) steps
    dt = t[1:] - t[:-1]
    # the next and previous values offset by the mean
    xn = x[1:] - mu
    xp = x[:-1] - mu

    # right now returning the signed version
    return xn - xp * np.exp(-eta * dt) / np.sqrt(-np.expm1(-2.0 * eta * dt))


def variance(
    t, x, eta: float, mu: float = 0.0
) -> float:
    """
    Returns an analogue of the weighted average of squares.
    D = (1/(n-1)) * sum { [(x_t - mu) - (x_{t-1} - mu)*exp(-eta*dt)] / (1 - exp(-2*eta*dt)) }
    This is the variance of the stable distribution.
    """
    # the time (or position) steps
    dt = t[1:] - t[:-1]
    # the next and previous values offset by the mean
    xn = x[1:] - mu
    xp = x[:-1] - mu

    return np.mean(
        np.square(xn - xp * np.exp(-eta * dt)) / (-np.expm1(-2.0 * eta * dt))
    )


def deta_variance(
    t, x, eta: float, mu: float = 0.0
) -> float:
    """
    Returns the derivative of the `variance` function with respect to eta.
    WARNING: there seem to be numerical issues at small eta, and eta will be small.
    """
    dt = t[1:] - t[:-1]
    xn = x[1:] - mu
    xp = x[:-1] - mu
    exp_etadt = np.exp(-eta * dt)
    expm1_2etadt = np.expm1(-2.0 * eta * dt)

    terms = (
        2.0
        * dt
        * exp_etadt
        * (xn - xp * exp_etadt)
        * (xp - xn * exp_etadt)
        / np.square(expm1_2etadt)
    )
    return terms.mean()


def mu(t, x, eta: float) -> float:
    """
    Returns the appropriately weighted mu given eta.
    """
    num, den = _mu_one(t, x, eta)
    return num / (den + 1e-6)


def mu_list(data, eta) -> float:
    """
    Returns the mu for a collection of samplings, properly weighting all together.
    """
    nums, dens = zip(*[_mu_one(t, x, eta) for t, x in data])
    return np.sum(nums) / (np.sum(dens) + 1e-6)


def _mu_one(t, x, eta: float) -> float:
    """
    Returns the numerator and denominator of an appropriately weighted mu given
    eta for a single t, x set
    """
    dt = t[1:] - t[:-1]
    xn, xp = x[1:], x[:-1]
    exp_etadt = np.exp(-eta * dt)
    expm1_etadt = np.expm1(-eta * dt)

    num = (xn - xp * exp_etadt) / (1.0 + exp_etadt)
    den = -expm1_etadt / (1.0 + exp_etadt)
    return num.sum(), den.sum()

# %%
class VanillaOU(nn.Module):
    def __init__(self, 
                 mean_rev_speed=None, 
                 mean_rev_level=None, 
                 vola=None, 
                 num_seq=1, 
                 num_node=1,
                 mode='train', 
                 device='cpu'):
        '''
        Modified from 
            https://github.com/jwergieluk/ou_noise/tree/master/ou_noise
            https://github.com/felix-clark/ornstein-uhlenbeck/blob/master/ornstein_uhlenbeck.py
            https://github.com/369geofreeman/Ornstein_Uhlenbeck_Model/blob/main/research.ipynb
        Args:
            mean_rev_speed: [bs/1, 1] or scalar
            mean_rev_level: [bs/1, 1] or scalar
            vola: [bs/1, 1] or scalar
            num_seq: when training mode, the num_seq will be automatically the number of batch size; 
                     when synthetic mode, the num_seq will be the number of sequences to generate
            mode: can be 'training' or 'synthetic'
            device:  
        '''
        
        super(VanillaOU, self).__init__()
        if mode == 'train': # TODO: for now it only considers parameters to optimize
            speed = torch.rand((num_seq, 1), device=device)
            # speed = torch.tensor(1e-5, device=device).double()
            self.mean_rev_speed = nn.Parameter(speed, requires_grad=True)
            
            level = torch.rand((num_seq, 1), device=device)
            self.mean_rev_level = nn.Parameter(level, requires_grad=True)
            # vola = torch.rand((num_seq, 1), device=device)
            # self.vola = nn.Parameter(vola, requires_grad=True)

            # level = torch.tensor(0.64, device=device)
            # self.mean_rev_level = nn.Parameter(level, requires_grad=False)
            vola = torch.tensor(1e-3, device=device).double()
            self.vola = torch.relu(nn.Parameter(vola, requires_grad=False))
        elif mode == 'synthetic':
            assert mean_rev_speed is not None
            self.mean_rev_speed = mean_rev_speed
            self.mean_rev_level = mean_rev_level
            self.vola = vola
        else:
            raise Exception('It is not a compatible mode')
            
        self.num_seq = num_seq
        self.device = device
        assert self.mean_rev_speed >= 0
        assert self.vola >= 0
        

    def variance(self, t, speed=None, vola=None):
        '''
        The variances introduced by the parameter vola, time difference and Wiener process (Gaussian noise)
        Args:
            t: 
        '''
        speed = speed if speed is not None else self.mean_rev_speed
        vola = vola if vola is not None else self.vola
        return vola * vola * (1.0 - torch.exp(- 2.0 * speed * t)) / (2 * speed + 1e-6)

    def std(self, t, speed=None, vola=None):
        '''
        Args:
            t: [num_seq/bs, num_node, times] usually is the time difference of a sequence
        '''
        return torch.sqrt(self.variance(t, speed, vola))

    def mean(self, x0, t, speed=None, level=None):
        '''
        Args:
            x0: 
            t: 
        '''
        speed = speed if speed is not None else self.mean_rev_speed
        level = level if level is not None else self.mean_rev_level
        return x0 * torch.exp(-speed * t) + (1.0 - torch.exp(- speed * t)) * level

    def logll(self, x, t, speed=None, level=None, vola=None):
        """
        Calculates log likelihood of a path
        Args:
            t: [num_seq/bs, time_step]
            x: [num_seq/bs, time_step] it should be the same size as t
        Return:
            log_pdf: [num_seq/bs, 1]
        """
        speed = speed if speed is not None else self.mean_rev_speed
        level = level if level is not None else self.mean_rev_level
        vola = vola if vola is not None else self.vola
        
        dt = torch.diff(t)
        dt = torch.log(dt) # TODO
        mu = self.mean(x, dt, speed, level)
        sigma = self.std(dt, speed, vola)
        var = self.variance(dt, speed, vola)

        # dist = torch.distributions.normal.Normal(loc=mu, scale=var)
        # log_pdf = dist.log_prob(x).sum(-1)
        log_scale = torch.log(sigma) / 2
        log_pdf = -((x - mu) ** 2) / (2 * var) - log_scale - torch.log(torch.sqrt(2 * torch.tensor(math.pi,device=device)))
        log_pdf = log_pdf.sum(-1)
        
        return log_pdf

    def simulate_path(self, x0, t, items=None):
        """ 
        Simulates a sample path or forward based on the parameters (speed, level, vola)
        dX = speed*(level-X)dt + vola*dB
        ** the num_node here can be considered as multivariate case of OU process 
            while the correlations between nodes wdo not matter
        Args:
            x0: [num_seq/bs, num_node] the initial states for each node in each sequences
            t: [num_seq/bs, time_step] the time points to sample (or interact);
                It should be the same for all nodes
            items: 
        Return: 
            x_pred: [num_seq/bs, num_node, time_step-1]
        """
        assert len(t) > 0
        num_seq, time_step = t.shape
        num_node = x0.shape[1]

        dt = torch.diff(t).unsqueeze(1) 
        dt = torch.tile(dt, (1, num_node, 1)) # [bs, num_node, time-1]
        dt = torch.log(dt) # TODO to find the right temperature of time difference in different real-world datasets

        scale = self.std(dt) # [bs, num_node, t-1]
        noise = torch.randn(size=scale.shape, device=self.device)
        
        x_last = x0 
        x_pred = []
        for i in range(1, time_step):
            x_next = self.mean(x_last, dt[..., i-1])  # [bs, num_node, 1]
            x_next = x_next + noise[..., i-1] * scale[..., i-1]
            x_pred.append(x_next)
            
            x_last = x_next

        return torch.stack(x_pred, -1)
